# %%
import tensorflow as tf 
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import sys

# %%
# img=cv2.imread("./data/high-res-chimpanzee-alone.jpeg")
# img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# #plt.imshow(img)
# img=cv2.resize(img,(32,32))
# plt.imshow(img)

# %%
sys.path.insert(0,"./utils")
import util
img2 = util.resize_image("./data/high-res-chimpanzee-alone.jpeg",(32,32))
plt.imshow(img2)
